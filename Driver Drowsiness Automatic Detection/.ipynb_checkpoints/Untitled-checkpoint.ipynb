# %%
import cv2
import glob

images = sorted(glob.glob("sample/video/no drowsy/*.png"))

fps = 30  
out = cv2.VideoWriter(
    "sample3.mp4",
    cv2.VideoWriter_fourcc(*"mp4v"),
    fps,
    (227,227)
)

for img_path in images:
    frame = cv2.imread(img_path)
    frame = cv2.resize(frame, (227,227))
    out.write(frame)

out.release()
